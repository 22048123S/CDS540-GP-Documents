# %%
accs = [
    0.6648,
    0.6677,
    0.7273,
    0.7082,
    0.7379,
    0.7395,
    0.7484,
    0.7512,
    0.7567,
    0.7198,
    0.7684,
    0.7400,
    0.7717,
    0.7219,
    0.7701,
    0.7747,
    0.7867,
    0.7397,
    0.7691,
    0.7724,
    0.7695,
    0.7802,
    0.7893,
    0.7811,
    0.7844,
    0.7545,
    0.7828,
    0.7608,
    0.7796,
    0.7648,
]

# %%
from matplotlib import pyplot as plt

plt.figure(figsize=(10,6))
plt.plot(accs)
plt.xlabel("Training Epochs")
plt.ylabel("Test Accuracy")
plt.title("Learning Curve for {} Epochs".format(len(accs)))
# Out:
# Text(0.5, 1.0, 'Learning Curve for 30 Epochs')
